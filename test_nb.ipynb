# %% [markdown]
# # Packages

# %%
import json
import spacy
from tqdm import tqdm

# %% [markdown]
# # TITLE

# %% [markdown]
# First we try to xy.
# - 1
# - 2

# %% [markdown]
# ## Analysis

# %%
with open("./all_songs.json") as f:
    songs_dict = json.load(f)

# %% [markdown]
# # Spacy

# %%
#Spacy muss gedownloaded werden mit : pip install -U pip setuptools wheel   und    pip install spacy 
# 	de_core_news_sm-3.5.0-py3-none-any.whl (muss gedownloaded werden -> https://spacy.io/models/de/)

nlp = spacy.load("de_core_news_sm")

list_of_nouns, list_of_pronouns = [], []

for song_id in tqdm(range(len(songs_dict["Prototyp"]))):

    lyrics_from_song = songs_dict["Prototyp"][str(song_id)]["lyrics"]
    doc = nlp(lyrics_from_song)

    # Ausgabe lediglich von Wörtern, die Nomen und Pronomen sind:
    for token in doc: 
        if token.pos_ == "NOUN":
            list_of_nouns.append(token.text)
        elif token.pos_ == "PRON":
            list_of_pronouns.append(token.text)
        else:
            pass
# Out:
# 100%|██████████| 88/88 [00:16<00:00,  5.38it/s]

# %%
print(f"{len(list_of_nouns)} nouns were found.")
print(f"{len(list_of_pronouns)} pronouns were found.")
# Out:
# 7399 nouns were found.
# 5563 pronouns were found.

# %%
distinct_nouns = sorted(list(set(list_of_nouns)))
distinct_pronouns = sorted(list(set(list_of_pronouns)))

# %%
print(f"{len(distinct_nouns)} distinct nouns were found.")
print(f"{len(distinct_pronouns)} distinct pronouns were found.")
# Out:
# 2387 distinct nouns were found.
# 119 distinct pronouns were found.

# %%
distinct_nouns
# Out:
# ['.',
#  '12Embed',
#  '1Embed',
#  '70s',
#  ':]',
#  'A',
#  'A.C.A.',
#  'A2',
#  'ADDICTED',
#  'ADEL',
#  'ADORE',
#  'AFTER',
#  "AIN'T",
#  'AKON',
#  'ALANIS',
#  'ALLEN',
#  'ALONE',
#  'ALWAYS',
#  'AM',
#  'AMERICA',
#  'ANIMALS',
#  'APPLAUS',
#  'ARETHA',
#  'AROUND',
#  'ASAF',
#  'ASCHENFLUG',
#  'AUFRECHT',
#  'AUGENBLING',
#  'AVICII',
#  'AVIDAN',
#  'Abend',
#  'Abendbrot',
#  'Abrissbirne',
#  'Abstand',
#  'Accordingly',
#  'Achter',
#  'Achterbahn',
#  'Adel',
#  'Adern',
#  'Affe',
#  'Affekt',
#  'Affen',
#  'Affer',
#  'After',
#  'Ah',
#  'Aha',
#  'Akten',
#  'Alaska',
#  'Albumversion',
#  'Alder',
#  'Alkohol',
#  'All',
#  'Alligatoah',
#  'Alltag',
#  'Alter',
#  'Although',
#  'Altlast',
#  'Amen',
#  'Amine',
#  'Amoklauf',
#  'Anblick',
#  'And',
#  'Andern',
#  'Anfang',
#  'Angel',
#  'Anglo-Chinese',
#  'Angst',
#  'Another',
#  'Anschlag',
#  'Antrieb',
#  'Anwalt',
#  'Aphrodite',
#  'Applaus',
#  'Apuleius',
#  'Arie',
#  'Arm',
#  'Armee',
#  'Armen',
#  'Arsch',
#  'Arschgeweih',
#  'Art',
#  'Arzt',
#  'Asche',
#  'Ascheregen',
#  'Asi',
#  'Asphalt',
#  'Ast',
#  'Astronaut',
#  'Astronaut8Embed',
#  'Atem',
#  'Atemzug',
#  'Atmen',
#  'Atom',
#  'Attentäter',
#  'Atzen',
#  'Au',
#  'Aufbruch',
#  'Aufgaben',
#  'Auflage',
#  'Aufsicht',
#  "Aufsteh'n",
#  'Auge',
#  'Augen',
#  'Augenblick',
#  'August',
#  'Augusti',
#  'Aula',
#  'Ausblick',
#  'Ausgang',
#  'Ausm',
#  'Ausreden',
#  'Aussicht',
#  'Ausweg',
#  'Autofahren',
#  'Autos',
#  'Außergewöhnliches',
#  'Axt',
#  'Aye',
#  'BACK',
#  'BAUCH',
#  'BEATRICE',
#  'BENDZKO',
#  'BERG',
#  'BEYONCÉ',
#  'BIS',
#  'BITCH',
#  'BITTER',
#  'BLEIBEN',
#  'BLURRED',
#  'BONNIE',
#  'BRITNEY',
#  'BROT',
#  'BRUNO',
#  'Babe',
#  'Baby',
#  'Back',
#  'Bad',
#  'Baden',
#  'Badze',
#  'Bagger',
#  'Bahn',
#  'Bahnen',
#  'Bahnhof',
#  'Bajang',
#  'Balkon',
#  'Ball',
#  'Ballast',
#  'Bambule',
#  'Bande',
#  'Bands',
#  'Bank',
#  'Banken',
#  'Bar',
#  'Barbecue',
#  'Barkeeper',
#  'Bars',
#  'Bart',
#  'Basketball',
#  'Bau',
#  'Bauch',
#  'Bauchgefühl',
#  'Baumarkt',
#  'Bayern',
#  'Beamten',
#  'Beat',
#  'Beats',
#  'Beatzarre',
#  'Becher',
#  'Bedacht',
#  'Befehl',
#  'Begegnung',
#  'Begeisterung',
#  'Beginner',
#  'Behörde',
#  'Bein',
#  'Beißer',
#  'Bereicherung',
#  'Bereit',
#  'Berg',
#  'Beruf',
#  'Bescheid',
#  'Besitze',
#  'Besoffen',
#  'Besseres',
#  'Beste',
#  'Besteck',
#  'Bestell',
#  'Besten',
#  'Besuch',
#  'Bett',
#  'Bewahr',
#  'Bier',
#  'Bierflasche',
#  'Bild',
#  'Bilder',
#  'Bildern',
#  'Bin',
#  'Bitte',
#  'Blahnik',
#  'Blatt',
#  'Blau',
#  'Blei',
#  'Bleib',
#  'Blick',
#  'Blinder',
#  'Block',
#  'Blut',
#  'Blutsaugend',
#  'Bobby',
#  'Bock',
#  'Boden',
#  'Bohnenviertel',
#  'Bombe',
#  'Bomben',
#  'Bonnie',
#  'Bono',
#  'Bord',
#  'Bordstein',
#  'Boxen',
#  'Boxentürme',
#  'Brachte',
#  'Brat',
#  'Brauch',
#  'Braucht',
#  'Braut',
#  'Brennpaste',
#  'Brett',
#  'Breuiarium',
#  'Briefe',
#  'Brot',
#  'Brust',
#  'Bräute',
#  'Bräuten',
#  'Brötchen',
#  'Brüchen',
#  'Brücke',
#  'Brücken',
#  'Buch',
#  'Bude',
#  'Bundestag',
#  'Buntstift',
#  'Burger',
#  'Bus',
#  'Busen',
#  'But',
#  'Bye-bye',
#  'Bäcker',
#  'Bässe',
#  'Büchern',
#  "CAN'T",
#  'CANDY',
#  'CAPE',
#  'CASCADA',
#  'CEE-LO',
#  'CHANGES',
#  'CHEATING',
#  'CHÉRIE',
#  'CIDDY',
#  'CLA$$IC',
#  'CLARE',
#  'CLARITY',
#  'CONTROL',
#  'CRAVEIRO',
#  'CRESPO',
#  'CROOKERS',
#  'CROSS',
#  'CRUSH',
#  'Caught',
#  'Champagnerfeten',
#  'Chance',
#  'Chancen',
#  'Chapter',
#  'Chef',
#  'Chick',
#  'Chicks',
#  'Children',
#  'Chinese',
#  'Chorus',
#  'Citybrunch',
#  'Clavigero',
#  'Cliqu',
#  'Clown',
#  'Club',
#  'Clubs',
#  'Cole',
#  'Command',
#  'ContributorSchwesterherz',
#  'ContributorsAlles',
#  'ContributorsApplaus',
#  'ContributorsAstronaut',
#  'ContributorsBauch',
#  'ContributorsBilder',
#  'ContributorsDiese',
#  'ContributorsDu',
#  'ContributorsEin',
#  'ContributorsEinmal',
#  'ContributorsErkläre',
#  'ContributorsGeboren',
#  'ContributorsHerz',
#  'ContributorsKeine',
#  'ContributorsLeider',
#  'ContributorsLieder',
#  'ContributorsMillionen',
#  'ContributorsMusik',
#  'ContributorsNe',
#  'ContributorsOhne',
#  'ContributorsPflaster',
#  'ContributorsRadio',
#  'ContributorsSchönste',
#  'ContributorsSo',
#  'ContributorsStadtaffe',
#  'ContributorsTranslationsEnglishIrgendwie',
#  'ContributorsTranslationsEnglishTausend',
#  'ContributorsTraum',
#  'ContributorsUniversum',
#  'Copperfield',
#  'Cops',
#  'Cosijopii',
#  'Couch',
#  'Cover',
#  'Crack',
#  'Cricket',
#  'Cro',
#  'Cuz',
#  "D'AGOSTINO",
#  'DAVID',
#  'DEIN',
#  'DEINER',
#  'DING',
#  'DIRTY',
#  'DISCO',
#  'DJ',
#  "DOESN'T",
#  "DON'T",
#  'DOWN',
#  'DU',
#  'Dach',
#  'Dag-Alexis',
#  'Dame',
#  'Dank',
#  'Danke',
#  'Dasyus',
#  'Date',
#  'Dauerflug',
#  'Dauerschleife',
#  'Dauerwelle',
#  'Daumen',
#  'Dealer',
#  'Deckung',
#  'Deichkind',
#  'Denk',
#  'Denkt',
#  'Denn—',
#  'Denyo',
#  'Designerschuhe',
#  'Details',
#  'Deutschrap',
#  'Devilry',
#  'Devils',
#  'Digga',
#  'Dimension',
#  'Ding',
#  'Dinge',
#  'Dingen',
#  'Disco',
#  'Discorides',
#  'Diät',
#  'Dorf',
#  'Dr.',
#  'Drache',
#  'Dreck',
#  'Drehen',
#  'Dreier',
#  'Drink',
#  'Drinks',
#  'Drogen',
#  'Druck',
#  'Dschungel',
#  'Dunkel',
#  'Dunkelheit',
#  'Dunkeln',
#  'Durchströmen',
#  'Dynamite',
#  'EIERMANN',
#  'ENJOY',
#  'ENTRE',
#  'EVERYBODY',
#  'EVERYTHING',
#  'Easy',
#  'Eazy-E',
#  'Ecke',
#  'Ecken',
#  'Eden',
#  'Eh',
#  'Ehe',
#  'Eighties',
#  'Einzelteile',
#  'Eis',
#  'Electro',
#  'Elefanten',
#  'ElefantenEmbed',
#  'Eltern',
#  'Embed',
#  'Emos',
#  'Empire',
#  'Ende',
#  'Endorphine',
#  'Endorphinen',
#  'Energiesparlampe',
#  'Enge',
#  'Enkel',
#  'Entdecke',
#  'Entscheidung',
#  'Entscheidungen',
#  'Entschluss',
#  'Epic',
#  "Erbarm'n",
#  'Erdboden',
#  'Erde',
#  'Erdumlaufbahn',
#  'Erfolg',
#  'Ergebnis',
#  'Erinner',
#  'Erinnerung',
#  'Erkläre',
#  'Ernst',
#  'Erscheinung',
#  'Ersguterjunge',
#  'Ersten',
#  'Erster',
#  'Ertränken',
#  'Erwacht',
#  'Erzähl',
#  'Essen',
#  'Est',
#  'Et',
#  'Ethiopic',
#  'Euphorie',
#  'Even',
#  'Ewigkeit',
#  'FEAT',
#  'FEEL',
#  'FEHLERFREI',
#  'FETTES',
#  'FIELDS',
#  'FINGER',
#  'FLAG',
#  'FLAGGE',
#  'FLAWS',
#  'FLO',
#  'FLOW',
#  'FOREVER',
#  'FOSTER',
#  'FRASER',
#  'FROM',
#  'FURY',
#  'FUSSBALL',
#  'Facebook',
#  'Faden',
#  'Fahr',
#  'Fahrrad',
#  'Fahrt',
#  'Fall',
#  'Falte',
#  'Fame',
#  'Familie',
#  'Fang',
#  'Fanta',
#  'Fantasie',
#  'Fantastischen',
#  'Farbe',
#  'Farben',
#  'Fass',
#  'Fassung',
#  'Fast-Food',
#  'Fasti',
#  'Fata',
#  'Father',
#  'Faust',
#  'Faxen',
#  'Feather',
#  'Fehler',
#  'Fehlern',
#  'Feiern',
#  'Feiertage',
#  'Feiertagen',
#  'Feind',
#  'Feinde',
#  'Felder',
#  'Fell',
#  'Fenster',
#  'Fensterglas',
#  'Ferne',
#  'Fernsehen',
#  'Fernsehturm',
#  'Festhalten',
#  'Feuer',
#  'Feuerrädern',
#  'Feuerstarter',
#  'Feuerwerk',
#  'Feuerzeug',
#  'Fick',
#  'Figur',
#  'Film',
#  'Finger',
#  'Fire',
#  'Firma',
#  'Fitness',
#  'Five',
#  'Flammen',
#  'Flash',
#  'Flatscreen',
#  'Flausen',
#  'Fleck',
#  'Fledermausland',
#  'Fleisch',
#  'Fleischerei',
#  'Fliege',
#  'Fliegen',
#  'Flocke',
#  'Flower',
#  'Flug',
#  'Flugbahn',
#  'Flügel',
#  'Forster',
#  'Fotoalbum',
#  'Fotos',
#  'Frag',
#  'Fragen',
#  'Frankfurt-City-Girls',
#  'Frau',
#  'Frauen',
#  'Frauenchor',
#  'Freitag',
#  'Fressen',
#  'Freude',
#  'Freunde',
#  'Freunden',
#  'Freundeskreis',
#  'Freundin',
#  'Freundschaft',
#  'Frieden',
#  'Friedhof',
#  'Frisur',
#  'Frust',
#  'Frühstück',
#  'Funken',
#  'Fuß',
#  'Fußspurn',
#  'Fäden',
#  'Fässern',
#  'Füchse',
#  'Füßen',
#  'GAMES',
#  "GANGSTA'S",
#  'GANZ',
#  'GEBOREN',
#  'GEFÜHL',
#  'GEHÖRT',
#  'GIRL',
#  'GLASS',
#  'GLOW',
#  'GLYNNE',
#  'GO',
#  'GONE',
#  'GRIECHISCHER',
#  'GT',
#  'GUIDO',
#  'Galaxy',
#  'Galland',
#  'Galopp',
#  'Gandhi',
#  'Gangster',
#  'Ganze',
#  'Ganzen',
#  'Garbhâdhâna',
#  'Garten',
#  'Gassen',
#  'Gay',
#  'Geb',
#  'Geboren',
#  'Geburt',
#  'Geburtstag',
#  'Gedanken',
#  'Gedankengeister',
#  'Gedränge',
#  'Gefangen',
#  'Gefühl',
#  'GefühlEmbed',
#  'Gegenteil',
#  'Gegner',
#  'Geh',
#  'Gehirn',
#  'Geier',
#  'Geigen',
#  'Geil',
#  'Geister',
#  'Geld',
#  'Geldschein',
#  'Geliebten',
#  'Genetikk',
#  'Genie',
#  'Gepäck',
#  'GepäckEmbed',
#  'Gervase',
#  'Gesaufe',
#  'Geschenk',
#  'Geschichte',
#  'Geschichten',
#  'Gesicht',
#  'Gesichter',
#  'Gesichtern',
#  'Getränk',
#  'Gewinnen',
#  'Gewissen',
#  'Gewissens',
#  'Gewissheit',
#  'Ghost',
#  'Ghoul',
#  'Gib',
#  'Gibber',
#  'Gieß',
#  'Gin',
#  'Ging',
#  'Gipfel',
#  'Girls',
#  'Gitarre',
#  'Give',
#  'Glanz',
#  'Glas',
#  'Glaub',
#  'Glauben',
#  'Gleiche',
#  'Gläser',
#  'Glück',
#  'Glücksmoment',
#  'Gold',
#  'Goldfisch',
#  'Gott',
#  'Graaaaaad',
#  'Grab',
#  'Graben',
#  'Grad',
#  'Gramm',
#  'Grasding',
#  'Greisenheim',
#  'Grenze',
#  'Grenzen',
#  'Griechen',
#  'Grimasse',
#  'Grindin',
#  'Großangriff',
#  'Großes',
#  'Großstadt',
#  'Grund',
#  'Größte',
#  'Grüße',
#  'Grüßen',
#  'Guck',
#  'Gute',
#  'Gutes',
#  'HALB',
#  'HALLELUJA',
#  'HAMBURGER',
#  'HANGOVER',
#  'HAPPEN',
#  'HARD',
#  'HAUS',
#  'HAYLEY',
#  'HEAL',
#  'HERZ',
#  'HINTERLAND',
#  'HOFFNUNG',
#  'HOLES',
#  'HOME',
#  'HOT',
#  'HOTEL',
#  'HOUSE',
#  'Haare',
#  'Haaren',
#  'Hab',
#  "Hab'n",
#  'Hackfleisch',
#  'Hafen',
#  'Hai',
#  'Haken',
#  'Halbsemester',
#  'Hals',
#  'Halt',
#  'Hammer-Tag',
#  'Hand',
#  'Handy',
#  'Hass',
#  'Haufen',
#  'Hauptsache',
#  'Haus',
#  'Hause',
#  'Hausmann',
#  'Haustür',
#  'Haut',
#  'Have',
#  'Hawaii',
#  'He',
#  'Heiderstums',
#  'Heim',
#  'Heimat',
#  'Heimatstadt',
#  'Held',
#  'Her',
#  'Herz',
#  'Herzen',
#  'Herzschlag',
#  'Highheels',
#  'Himmel',
#  'Hin',
#  'Hinterhof',
#  'Hinterland',
#  'His',
#  'Ho-och',
#  'Hobby',
#  'Hoch',
#  'Hochhäuser',
#  'Hof',
#  'Hoffnung',
#  'Hofstaat',
#  'Hol',
#  'Holz',
#  'Hook',
#  'Horde',
#  'Hosen',
#  'However',
#  'Huch',
#  'Hummeln',
#  'Hund',
#  'Hunde',
#  'Hungertod',
#  'Hut',
#  'Hä',
#  'Häcksler',
#  'Hälfte',
#  'Hände',
#  'Hätte',
#  'Häuser',
#  'Hör',
#  "I'LL",
#  "I'M",
#  "I'VE",
#  'IF',
#  'IMPOSSIBLE',
#  'INSOMNIA',
#  'IRONIC',
#  "IT'S",
#  'Idee',
#  'Ideen',
#  'Imperator',
#  'Ina',
#  'Information',
#  'Inquisition',
#  'Inseln',
#  'Instrumentelle',
#  'Interesse',
#  'Interlude',
#  'Irgendwas',
#  'Irgendwie',
#  'Isi',
#  'Italy',
#  'Ito',
#  'Its',
#  'JA',
#  'JASON',
#  'JEIN',
#  'JENNIFER',
#  'JESUS',
#  'JOHNNY',
#  'JORDIN',
#  'JOY',
#  'JUICY',
#  'JUNGE',
#  'JUNO',
#  'JUNX',
#  'JUPITER',
#  'Ja',
#  'Jacke',
#  'Jackpot',
#  'Jahr',
#  'Jahre',
#  'Jahren',
#  'Jamal',
#  'Janine',
#  'Jeans',
#  'Jesus',
#  'Jet',
#  'Jibbit',
#  'Job',
#  'Joggen',
#  'Johnny',
#  'Jordans',
#  'Julischnee',
#  'Junge',
#  'Jungs',
#  'Jägermeister',
#  'KELLY',
#  'KIND',
#  'KNOW',
#  'KOPF',
#  'KRANICHE',
#  'KROKODIL',
#  'KRYPTONITE',
#  'Kabinett',
#  'Kaffee',
#  'Kalender',
#  'Kamera',
#  'Karma',
#  'Karre',
#  'Karriere',
#  'Karte',
#  'Karten',
#  'Karussell',
#  'Kassette',
#  'Kassierer',
#  'Katastrophe',
#  'Katheterschlauch',
#  'Katze',
#  'Kaufen',
#  'Kaufmannsladen',
#  'Kaviar',
#  'Kehle',
#  'Keller',
#  'Kellnerin',
#  'Kenn',
#  'Kerngesund',
#  'Ketten',
#  'Kick',
#  'Kids',
#  'Kiez',
#  'Kiffen',
#  'Killerlady',
#  'Kilo',
#  'Kilometern',
#  'Kind',
#  'Kinder',
#  'Kinderhände',
#  'King',
#  'Kiosk',
#  'Kippe',
#  'Kippen',
#  'Kiste',
#  'Klamotten',
#  'Klappe',
#  'Klavier',
#  'Kleid',
#  'Kleider',
#  'Kleiderschrank',
#  'Kleinen',
#  'Kleinigkeit',
#  'Klima',
#  'Kling-linge-ling',
#  'Kloß',
#  'Kläffer',
#  'Knall',
#  'Knast',
#  'Kneipe',
#  'Knopf',
#  'Kohle',
#  'Kollegah',
#  'Koma',
#  'Komet',
#  'Kometen',
#  'Kommi',
#  'Kompass',
#  'Kontrolle',
#  'Konzerten',
#  'Kopf',
#  'Kopf10Embed',
#  'Kopfhörer',
#  'Korken',
#  'Kotzen',
#  'Krallen',
#  'Kram',
#  'Krawall',
#  'Krawatte',
#  'Kreditkarten',
#  'Kreis',
#  'Kreise',
#  'Kreuzungen',
#  'Kribbeln',
#  'Kriege',
#  'Krieger',
#  'Kräne',
#  "Ku'damm",
#  'Kulissen',
#  'Kultur',
#  'Kumpels',
#  'Kur',
#  'Kurven',
#  'Kuss',
#  'Kussmund',
#  'Käfig',
#  'König',
#  'Köpfe',
#  'Körper',
#  'Körperwelten',
#  'Köter',
#  'L.A',
#  'LADIES',
#  'LANGE',
#  'LASS',
#  'LEBT',
#  'LEMON',
#  'LEONA',
#  'LEWIS',
#  'LICHTER',
#  'LIEBE',
#  'LIECHTENSTEIN',
#  'LIED',
#  'LILA',
#  'LIQUID',
#  'LIVIN',
#  'LOKALPILOTEN',
#  'LONESOME',
#  'LOSING',
#  'LOVE',
#  'LOVING',
#  'Labyrinth',
#  'Lacoste',
#  'Laden',
#  'Ladies',
#  'Lady',
#  'Lage',
#  'Land',
#  'Landung',
#  'Langeweile',
#  'Langsuior',
#  'Lass',
#  'Lassen',
#  'Last',
#  'Lauf',
#  'Laufe',
#  'Laune',
#  'Laura',
#  'Lauschgift',
#  'Leben',
#  'Lebens',
#  'Leber',
#  'Leck',
#  'Leere',
#  'Leiche',
#  'Leichen',
#  'Leid',
#  'Leihwagen',
#  'Leinen',
#  'Letzte',
#  'Letzten',
#  'Leuchten',
#  'Leute',
#  'Liang',
#  'Liber',
#  'Libri',
#  'Licht',
#  'Lichter',
#  'Lichtern',
#  'Liddell',
#  'Liebe',
#  'Lieber',
#  'Lieblingskleid',
#  'Lieblingslied',
#  'Lieblingslieder',
#  'Lieblingsplatten',
#  'Lied',
#  'Lieder',
#  'Lieg',
#  'Lilîtu',
#  'Limit',
#  'Lippen',
#  'Liste',
#  'Live',
#  'Loft',
#  'Lord',
#  'Lotto',
#  'Luft',
#  'Lungen',
#  'LyricsAlben',
#  'LyricsCHAPTER',
#  'LyricsDa',
#  'Lächeln',
#  'Lärm',
#  'Lässt',
#  'Löcher',
#  'Löchern',
#  'Löffel',
#  'Lösung',
#  'MADELINE',
#  'MAFIA',
#  'MAMMA',
#  'MARK',
#  'MC',
#  'MEAT',
#  'MEDLEY',
#  'MEINES',
#  'MENSCH',
#  ...]
